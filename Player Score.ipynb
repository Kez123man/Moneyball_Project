# %%
'''This Python module will conduct stage 6 of the Henderson Sports' analytical model, statstical application,
by creating a composite statistic that measures a player's general performance over a season relative to other people in 
this position (Adapted from: Holland and Shaw (2019).'''

# Import all the necessary libraries and the two datasets
import pandas as pd

performance_rating = pd.read_csv('file4.csv', low_memory=False)
performance_rating_GK = pd.read_csv('file4_GK.csv')

# Title: User Guide - Pandas
# Author: N/A
# Date: No date
# Code Version: 2.2
# Source: "https://pandas.pydata.org/docs/user_guide/index.html"

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
performance_rating
# Out:
#         Squad              Player  Fouls_Commited  Fouls_Won  Offsides  \
# 0      Alavés         Abdel Abqar            33.0       23.0       1.0
# 1      Alavés    Carlos Benavídez            38.0        9.0       1.0
# 2      Alavés      Antonio Blanco            36.0       40.0       0.0
# 3      Alavés        Rubén Duarte            31.0       30.0       0.0
# 4      Alavés    Andoni Gorosabel            29.0       41.0       0.0
# ...       ...                 ...             ...        ...       ...
# 30321     NaN  Sid Ahmed Aissaoui             NaN        NaN       NaN
# 30322     NaN         Erdem Çalık             NaN        NaN       NaN
# 30323     NaN       Adama Sidibeh             NaN        NaN       NaN
# 30324     NaN  Artem Prysyazhnyuk             NaN        NaN       NaN
# 30325     NaN    Araphat Mohammed             NaN        NaN       NaN
#
#        Crosses  Penalties_Won  Penalties_Conceded  Own_Goals  Ball_Recoveries  \
# 0          2.0            0.0                 2.0        1.0            109.0
# 1          4.0            0.0                 2.0        0.0             72.0
# 2         15.0            0.0                 0.0        0.0            160.0
# 3         70.0            0.0                 0.0        0.0             93.0
# 4         81.0            1.0                 1.0        0.0            164.0
# ...        ...            ...                 ...        ...              ...
# 30321      NaN            NaN                 NaN        NaN              NaN
# 30322      NaN            NaN                 NaN        NaN              NaN
# 30323      NaN            NaN                 NaN        NaN              NaN
# 30324      NaN            NaN                 NaN        NaN              NaN
# 30325      NaN            NaN                 NaN        NaN              NaN
#
#        ...  Position   Foot  Height_in_CM Contract_Expiration_Date  \
# 0      ...  Defender  right         188.0      2025-06-30 00:00:00
# 1      ...       NaN    NaN           NaN                      NaN
# 2      ...  Midfield  right         176.0      2027-06-30 00:00:00
# 3      ...  Defender   left         179.0      2026-06-30 00:00:00
# 4      ...  Defender  right         174.0      2024-06-30 00:00:00
# ...    ...       ...    ...           ...                      ...
# 30321  ...  Midfield  right         183.0      2026-06-30 00:00:00
# 30322  ...  Midfield  right           NaN      2026-06-30 00:00:00
# 30323  ...    Attack    NaN           NaN      2026-05-31 00:00:00
# 30324  ...  Midfield   left         180.0      2025-05-31 00:00:00
# 30325  ...  Midfield   left           NaN                      NaN
#
#              Agent_Name              Current_Club_Name  Market_Value_in_Eur  \
# 0              11MANGMT        Deportivo Alavés S.A.D.            3000000.0
# 1                   NaN                            NaN                  NaN
# 2                   NaN        Deportivo Alavés S.A.D.            5000000.0
# 3           CAA Stellar        Deportivo Alavés S.A.D.            2500000.0
# 4                   NaN        Deportivo Alavés S.A.D.            2500000.0
# ...                 ...                            ...                  ...
# 30321  Aniss Benchabane                PFK CSKA Moskva             150000.0
# 30322               NaN                     Pendikspor              50000.0
# 30323      Willie McKay  Saint Johnstone Football Club                  NaN
# 30324               NaN     ZAO FK Chornomorets Odessa                  NaN
# 30325               NaN      Fodbold Club Nordsjælland                  NaN
#
#        Highest_Market_Value_in_Eur  Touches  Usage_Rate_Per
# 0                        3000000.0   1032.0        5.676880
# 1                              NaN    628.0        3.454535
# 2                        5000000.0   1283.0        7.057594
# 3                        6000000.0   1024.0        5.632873
# 4                       10000000.0   1624.0        8.933385
# ...                            ...      ...             ...
# 30321                     150000.0      NaN             NaN
# 30322                      50000.0      NaN             NaN
# 30323                          NaN      NaN             NaN
# 30324                          NaN      NaN             NaN
# 30325                          NaN      NaN             NaN
#
# [30326 rows x 95 columns]

# %%
attack_performance_rating = performance_rating

# %%
# This function will create a 'Score' for the attacking players based on the criteria below
def calculate_performance_attack(row_att): 
    goals = (row_att['Goals_Minus_PK'] * 100)
    assists = row_att['Assists'] * 50
    pen_goals = row_att['Penalty_Goals'] * 50
    pen_miss = (row_att['Penalties_Attempted'] - row_att['Penalty_Goals']) * (-50)
    xG = row_att['Expected_xG'] * 2
    XG_GS = (row_att['Expected_xG'] - row_att['Goals']) * 5
    Prog_Carries = row_att['Carries_PrgC'] * 5
    Progression_PrgP = row_att['Progression_PrgP'] * 3
    Take_Ons_Succ = row_att['Take_Ons_Succ'] * 2
    Take_Ons_Succ_per = row_att['Take_Ons_Succ_Per'] * 10
    Tackles_won = row_att['Tackles_TklW']
    Interceptions = row_att['Interceptions']
    Blocks = row_att['Blocks']
    Clearances = row_att['Clearances']
    Crosses = row_att['Crosses']
    Foul_won = row_att['Fouls_Won']
    Offsides = row_att['Offsides'] * (-3)
    Penalties_Won = row_att['Penalties_Won'] * 5
    Penalties_Conceded = row_att['Penalties_Conceded'] * (-5)
    Own_Goals = row_att['Own_Goals'] * (-5)
    Ball_Recoveries = row_att['Ball_Recoveries']
    Aerial_Duels_Won = row_att['Aerial_Duels_Won']
    Aerial_Duels_Lost = row_att['Aerial_Duels_Lost'] 
    Aerial_Duels_Won_Per = row_att['Aerial_Duels_Won_Per'] * 10
    Challenges_Lost = row_att['Challenges_Lost'] * (-1)
    Y_card = row_att['Performance_CrdY'] * (-3)
    R_card = row_att['Performance_CrdR'] * (-5)
    
    return goals + assists + pen_goals + pen_miss + xG + XG_GS + Prog_Carries + Progression_PrgP + Take_Ons_Succ + Take_Ons_Succ_per + Tackles_won + Interceptions + Blocks  + Clearances + Challenges_Lost + Y_card + R_card + Crosses + Foul_won + Offsides + Penalties_Won + Penalties_Conceded + Own_Goals + Ball_Recoveries + Aerial_Duels_Won + Aerial_Duels_Lost + Aerial_Duels_Won_Per
    


# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
# Applying the function for attacking players to create a new column/variable 'Score'
attack_performance_rating['Score'] = attack_performance_rating.apply(calculate_performance_attack, axis=1)

# Arrange the data by the 'Score' column
attack_performance_rating = attack_performance_rating.sort_values(by='Score', ascending=False)

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
attack_performance_rating.head(10)
# Out:
#                 Squad             Player  Fouls_Commited  Fouls_Won  Offsides  \
# 260     Bayern Munich         Harry Kane            10.0       39.0      13.0
# 1616  Manchester City              Rodri            41.0       35.0       6.0
# 2079      Real Madrid    Jude Bellingham            32.0       72.0       4.0
# 621           Chelsea        Cole Palmer            23.0       26.0       6.0
# 1607  Manchester City         Phil Foden            14.0       60.0       5.0
# 76            Arsenal        Bukayo Saka            41.0       69.0       8.0
# 2378        Stuttgart    Serhou Guirassy            18.0       55.0      18.0
# 1395       Leverkusen      Florian Wirtz            23.0       27.0       6.0
# 2013        Paris S-G      Kylian Mbappé            19.0       38.0      20.0
# 2592       Villarreal  Alexander Sørloth            34.0       19.0      23.0
#
#       Crosses  Penalties_Won  Penalties_Conceded  Own_Goals  Ball_Recoveries  \
# 260      31.0            0.0                 0.0        0.0             55.0
# 1616     12.0            1.0                 0.0        0.0            235.0
# 2079     21.0            0.0                 0.0        0.0            118.0
# 621      81.0            1.0                 0.0        0.0            105.0
# 1607     89.0            0.0                 1.0        0.0            127.0
# 76      181.0            1.0                 0.0        0.0            155.0
# 2378      1.0            2.0                 0.0        0.0             39.0
# 1395     36.0            0.0                 0.0        0.0            143.0
# 2013     23.0            2.0                 0.0        0.0             47.0
# 2592      7.0            1.0                 0.0        0.0             57.0
#
#       ...   Foot  Height_in_CM  Contract_Expiration_Date      Agent_Name  \
# 260   ...  right         188.0       2027-06-30 00:00:00            CK66
# 1616  ...  right         191.0       2027-06-30 00:00:00  Pablo Barquero
# 2079  ...  right         186.0       2029-06-30 00:00:00             NaN
# 621   ...   left         189.0       2030-06-30 00:00:00    CAA Base Ltd
# 1607  ...   left         171.0       2027-06-30 00:00:00             NaN
# 76    ...   left         178.0       2027-06-30 00:00:00             NaN
# 2378  ...  right         187.0       2026-06-30 00:00:00           KGSMI
# 1395  ...  right         177.0       2027-06-30 00:00:00             NaN
# 2013  ...  right         178.0       2024-06-30 00:00:00             NaN
# 2592  ...   left         195.0       2028-06-30 00:00:00      Keypass AS
#
#                               Current_Club_Name  Market_Value_in_Eur  \
# 260                           FC Bayern München          110000000.0
# 1616              Manchester City Football Club          110000000.0
# 2079                 Real Madrid Club de Fútbol          180000000.0
# 621                       Chelsea Football Club           55000000.0
# 1607              Manchester City Football Club          130000000.0
# 76                        Arsenal Football Club          130000000.0
# 2378  Verein für Bewegungsspiele Stuttgart 1893           40000000.0
# 1395                Bayer 04 Leverkusen Fußball          110000000.0
# 2013          Paris Saint-Germain Football Club          180000000.0
# 2592           Villarreal Club de Fútbol S.A.D.           15000000.0
#
#       Highest_Market_Value_in_Eur  Touches  Usage_Rate_Per   Score
# 260                   150000000.0    995.0        3.734424  5367.2
# 1616                  110000000.0   3988.0       12.694977  4624.7
# 2079                  180000000.0   1897.0        6.616672  4581.7
# 621                    55000000.0   1754.0        6.326420  4534.4
# 1607                  130000000.0   2146.0        6.831349  4398.1
# 76                    130000000.0   1952.0        7.367984  4338.5
# 2378                   40000000.0   1064.0        4.060449  4261.6
# 1395                  110000000.0   2252.0        8.091987  4239.3
# 2013                  200000000.0   1264.0        4.515415  4231.0
# 2592                   20000000.0    797.0        3.506534  4217.1
#
# [10 rows x 96 columns]

# %%
# Filtering the data so it only includes players in attacking positions
condition_att = attack_performance_rating[attack_performance_rating['Sub_Position'].isin(['Right Winger', 'Left Winger', 'Second Striker', 'Centre-Forward', 'Attacking Midfield'])]

# Applying the created condition to create the attacking dataset 
attack_performance_rating_2 = condition_att

# Arranging the data by the 'Score' column 
attack_performance_rating_2 = attack_performance_rating_2.sort_values(by='Score', ascending=False)
attack_performance_rating_2.head(10)

# Title: Pandas DataFrame isin() Method
# Author: W3 Schools
# Date: No date
# Code Version: N/A
#Source: "https://www.w3schools.com/python/pandas/ref_df_isin.asp"

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#                 Squad             Player  Fouls_Commited  Fouls_Won  Offsides  \
# 260     Bayern Munich         Harry Kane            10.0       39.0      13.0
# 2079      Real Madrid    Jude Bellingham            32.0       72.0       4.0
# 621           Chelsea        Cole Palmer            23.0       26.0       6.0
# 1607  Manchester City         Phil Foden            14.0       60.0       5.0
# 76            Arsenal        Bukayo Saka            41.0       69.0       8.0
# 2378        Stuttgart    Serhou Guirassy            18.0       55.0      18.0
# 1395       Leverkusen      Florian Wirtz            23.0       27.0       6.0
# 2013        Paris S-G      Kylian Mbappé            19.0       38.0      20.0
# 2592       Villarreal  Alexander Sørloth            34.0       19.0      23.0
# 2076       RB Leipzig        Xavi Simons            32.0       70.0       1.0
#
#       Crosses  Penalties_Won  Penalties_Conceded  Own_Goals  Ball_Recoveries  \
# 260      31.0            0.0                 0.0        0.0             55.0
# 2079     21.0            0.0                 0.0        0.0            118.0
# 621      81.0            1.0                 0.0        0.0            105.0
# 1607     89.0            0.0                 1.0        0.0            127.0
# 76      181.0            1.0                 0.0        0.0            155.0
# 2378      1.0            2.0                 0.0        0.0             39.0
# 1395     36.0            0.0                 0.0        0.0            143.0
# 2013     23.0            2.0                 0.0        0.0             47.0
# 2592      7.0            1.0                 0.0        0.0             57.0
# 2076     76.0            2.0                 0.0        0.0            167.0
#
#       ...   Foot  Height_in_CM  Contract_Expiration_Date    Agent_Name  \
# 260   ...  right         188.0       2027-06-30 00:00:00          CK66
# 2079  ...  right         186.0       2029-06-30 00:00:00           NaN
# 621   ...   left         189.0       2030-06-30 00:00:00  CAA Base Ltd
# 1607  ...   left         171.0       2027-06-30 00:00:00           NaN
# 76    ...   left         178.0       2027-06-30 00:00:00           NaN
# 2378  ...  right         187.0       2026-06-30 00:00:00         KGSMI
# 1395  ...  right         177.0       2027-06-30 00:00:00           NaN
# 2013  ...  right         178.0       2024-06-30 00:00:00           NaN
# 2592  ...   left         195.0       2028-06-30 00:00:00    Keypass AS
# 2076  ...  right         179.0       2024-06-30 00:00:00   Darren Dein
#
#                               Current_Club_Name  Market_Value_in_Eur  \
# 260                           FC Bayern München          110000000.0
# 2079                 Real Madrid Club de Fútbol          180000000.0
# 621                       Chelsea Football Club           55000000.0
# 1607              Manchester City Football Club          130000000.0
# 76                        Arsenal Football Club          130000000.0
# 2378  Verein für Bewegungsspiele Stuttgart 1893           40000000.0
# 1395                Bayer 04 Leverkusen Fußball          110000000.0
# 2013          Paris Saint-Germain Football Club          180000000.0
# 2592           Villarreal Club de Fútbol S.A.D.           15000000.0
# 2076                     RasenBallsport Leipzig           80000000.0
#
#       Highest_Market_Value_in_Eur  Touches  Usage_Rate_Per   Score
# 260                   150000000.0    995.0        3.734424  5367.2
# 2079                  180000000.0   1897.0        6.616672  4581.7
# 621                    55000000.0   1754.0        6.326420  4534.4
# 1607                  130000000.0   2146.0        6.831349  4398.1
# 76                    130000000.0   1952.0        7.367984  4338.5
# 2378                   40000000.0   1064.0        4.060449  4261.6
# 1395                  110000000.0   2252.0        8.091987  4239.3
# 2013                  200000000.0   1264.0        4.515415  4231.0
# 2592                   20000000.0    797.0        3.506534  4217.1
# 2076                   80000000.0   1817.0        7.791595  4167.1
#
# [10 rows x 96 columns]

# %%
# Saving the attacking performance as CSV with new features
attack_performance_rating_2.to_csv('file_attack.csv', encoding='utf-8-sig', index=False)

# %%
midfield_performance_rating = performance_rating

# %%
# This function will create a 'Score' for the midfielders based on the criteria below
def calculate_performance_midfield(col_mid):
    goals = col_mid['Goals_Minus_PK'] * 50 
    assists = col_mid['Assists'] * 50
    pen_goals = col_mid['Penalty_Goals'] * 30
    pen_miss = (col_mid['Penalties_Attempted'] - col_mid['Penalty_Goals']) * (-30)
    Prog_Carries = col_mid['Carries_PrgC'] * 10
    Progression_PrgP = col_mid['Progression_PrgP'] * 10
    Take_Ons_Succ = col_mid['Take_Ons_Succ'] * 2
    Take_Ons_Succ_per = col_mid['Take_Ons_Succ_Per'] * 10
    Tackles_won = col_mid['Tackles_TklW'] * 3
    Interceptions = col_mid['Interceptions'] * 3
    Blocks = col_mid['Blocks'] * 3
    Clearances = col_mid['Clearances'] * 3
    Crosses = col_mid['Crosses']
    Foul_won = col_mid['Fouls_Won']
    Offsides = col_mid['Offsides'] * (-3)
    Penalties_Won = col_mid['Penalties_Won'] * 5
    Penalties_Conceded = col_mid['Penalties_Conceded'] * (-5)
    Own_Goals = col_mid['Own_Goals'] * (-5)
    Ball_Recoveries = col_mid['Ball_Recoveries']
    Aerial_Duels_Won = col_mid['Aerial_Duels_Won']
    Aerial_Duels_Lost = col_mid['Aerial_Duels_Lost'] 
    Aerial_Duels_Won_Per = col_mid['Aerial_Duels_Won_Per'] * 10
    Challenges_Att = col_mid['Dribblers_Challenged'] * 10
    Challenges_Tkl_per = col_mid['Per_Dribblers_Tkl_Succ'] * 5
    Challenges_Lost = col_mid['Challenges_Lost'] * (-2)
    Y_card = col_mid['Performance_CrdY'] * (-3)
    R_card = col_mid['Performance_CrdR'] * (-5)
    
    return goals + assists + pen_goals + pen_miss + Prog_Carries + Progression_PrgP + Take_Ons_Succ + Take_Ons_Succ_per + Tackles_won + Interceptions + Blocks  + Clearances + Challenges_Lost + Y_card + R_card+ Challenges_Att + Challenges_Tkl_per + Crosses + Foul_won + Offsides + Penalties_Won + Penalties_Conceded + Own_Goals + Ball_Recoveries + Aerial_Duels_Won + Aerial_Duels_Lost + Aerial_Duels_Won_Per
    
# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
# Applying the function for midfielders to create a new variable 'Score'
midfield_performance_rating['Score'] = midfield_performance_rating.apply(calculate_performance_midfield, axis=1)

# Arrange the data by the 'Score' column
midfield_performance_rating_1 = midfield_performance_rating.sort_values(by='Score', ascending=False)

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
# Filter the data so that it only keeps midfielders
condition_mid = (midfield_performance_rating_1['Position'] == 'Midfield') 

# Applying the filter to create the midfielder dataset
midfield_performance_rating_2 = midfield_performance_rating_1[condition_mid]

midfield_performance_rating_2 = midfield_performance_rating_2.sort_values(by='Score', ascending=False)
midfield_performance_rating_2.head(10)

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#                 Squad            Player  Fouls_Commited  Fouls_Won  Offsides  \
# 1616  Manchester City             Rodri            41.0       35.0       6.0
# 1628   Manchester Utd   Bruno Fernandes            41.0       28.0      13.0
# 455          Brighton       Pascal Groß            23.0       27.0       3.0
# 1892    Newcastle Utd   Bruno Guimarães            50.0      108.0       0.0
# 86            Arsenal   Martin Ødegaard            30.0       36.0       3.0
# 1521             Lyon  Maxence Caqueret            34.0       30.0       1.0
# 75            Arsenal       Declan Rice            34.0       13.0       2.0
# 1396       Leverkusen      Granit Xhaka            30.0       43.0       0.0
# 1000           Girona      Aleix García            29.0       36.0       1.0
# 332            Bochum      Kevin Stöger            36.0       63.0       1.0
#
#       Crosses  Penalties_Won  Penalties_Conceded  Own_Goals  Ball_Recoveries  \
# 1616     12.0            1.0                 0.0        0.0            235.0
# 1628    223.0            0.0                 0.0        0.0            200.0
# 455     238.0            0.0                 1.0        0.0            144.0
# 1892     32.0            0.0                 0.0        0.0            237.0
# 86       77.0            1.0                 0.0        0.0            158.0
# 1521     86.0            0.0                 1.0        0.0            236.0
# 75       60.0            0.0                 2.0        0.0            178.0
# 1396     10.0            0.0                 0.0        0.0            226.0
# 1000    192.0            0.0                 0.0        0.0            208.0
# 332     258.0            0.0                 0.0        0.0            210.0
#
#       ...   Foot  Height_in_CM  Contract_Expiration_Date           Agent_Name  \
# 1616  ...  right         191.0       2027-06-30 00:00:00       Pablo Barquero
# 1628  ...  right         179.0       2026-06-30 00:00:00    MRP.POSITIONUMBER
# 455   ...  right         181.0       2025-06-30 00:00:00                  NaN
# 1892  ...  right         182.0       2028-06-30 00:00:00    Bertolucci Sports
# 86    ...   left         178.0       2028-06-30 00:00:00           Nordic Sky
# 1521  ...  right         174.0       2027-06-30 00:00:00                  NaN
# 75    ...  right         188.0       2028-06-30 00:00:00                  NaN
# 1396  ...   left         186.0       2028-06-30 00:00:00  Signature - ISCM AG
# 1000  ...  right         173.0       2026-06-30 00:00:00         MagicPlayers
# 332   ...   left         175.0       2024-06-30 00:00:00         Kevin Stöger
#
#                                       Current_Club_Name  Market_Value_in_Eur  \
# 1616                      Manchester City Football Club          110000000.0
# 1628                    Manchester United Football Club           70000000.0
# 455              Brighton and Hove Albion Football Club            8000000.0
# 1892                     Newcastle United Football Club           85000000.0
# 86                                Arsenal Football Club           95000000.0
# 1521                                 Olympique Lyonnais           20000000.0
# 75                                Arsenal Football Club          110000000.0
# 1396                        Bayer 04 Leverkusen Fußball           20000000.0
# 1000                        Girona Fútbol Club S. A. D.           25000000.0
# 332   Verein für Leibesübungen Bochum 1848 – Fußball...            4000000.0
#
#       Highest_Market_Value_in_Eur  Touches  Usage_Rate_Per   Score
# 1616                  110000000.0   3988.0       12.694977  8342.5
# 1628                   90000000.0   2585.0       10.772180  7404.5
# 455                    12000000.0   3534.0       12.139324  7231.5
# 1892                   85000000.0   2734.0       11.389768  7184.5
# 86                     95000000.0   2326.0        8.779678  7088.5
# 1521                   25000000.0   2357.0       10.900430  6910.5
# 75                    110000000.0   2650.0       10.002642  6909.5
# 1396                   50000000.0   3558.0       12.784765  6868.0
# 1000                   25000000.0   3220.0       12.490787  6739.5
# 332                     6000000.0   2384.0       12.984042  6676.5
#
# [10 rows x 96 columns]

# %%
# Save the defenders CSV with new 'Score' feature
midfield_performance_rating_2.to_csv('file_mid.csv', encoding='utf-8-sig', index=False)

# %%
defence_performance_rating = performance_rating

# %%
# This function will create a 'Score' for the defenders based on the criteria below
def calculate_performance_defence(col_def):
    goals_def = col_def['Goals_Minus_PK'] * 25
    assists_def = col_def['Assists'] * 25
    pen_goals_def = col_def['Penalty_Goals'] * 15
    pen_miss_def = (col_def['Penalties_Attempted'] - col_def['Penalty_Goals']) * (-15)
    Prog_Carries_def = col_def['Carries_PrgC'] * 3
    Progression_PrgP_def = col_def['Progression_PrgP'] * 3
    Take_Ons_Succ_def = col_def['Take_Ons_Succ'] 
    Take_Ons_Succ_per_def = col_def['Take_Ons_Succ_Per'] 
    Tackles_won_def = col_def['Tackles_TklW'] * 5
    Interceptions_def = col_def['Interceptions'] * 5
    Blocks_def = col_def['Blocks'] * 5
    Clearances_def = col_def['Clearances'] * 5
    Crosses = col_def['Crosses']
    Foul_won = col_def['Fouls_Won']
    Penalties_Won = col_def['Penalties_Won'] * 5
    Penalties_Conceded = col_def['Penalties_Conceded'] * (-5)
    Own_Goals = col_def['Own_Goals'] * (-5)
    Ball_Recoveries = col_def['Ball_Recoveries']
    Aerial_Duels_Won = col_def['Aerial_Duels_Won']
    Aerial_Duels_Lost = col_def['Aerial_Duels_Lost'] 
    Aerial_Duels_Won_Per = col_def['Aerial_Duels_Won_Per'] * 10
    Challenges_Att_def = (col_def['Dribblers_Challenged']) * 15
    Challenges_Tkl_per_def = (col_def['Per_Dribblers_Tkl_Succ']) * 25
    Challenges_Lost_def = col_def['Challenges_Lost'] * (-3)
    Y_card_def = col_def['Performance_CrdY'] * (-3)
    R_card_def = col_def['Performance_CrdR'] * (-5)
    
    return goals_def + assists_def + pen_goals_def + pen_miss_def + Prog_Carries_def + Progression_PrgP_def + Take_Ons_Succ_def + Take_Ons_Succ_per_def + Tackles_won_def + Interceptions_def + Blocks_def  + Clearances_def + Challenges_Att_def + Challenges_Tkl_per_def + Challenges_Lost_def + Y_card_def + R_card_def + Crosses + Foul_won + Penalties_Won + Penalties_Conceded + Own_Goals + Ball_Recoveries + Aerial_Duels_Won + Aerial_Duels_Lost + Aerial_Duels_Won_Per

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
# Apply the defenders' 'Score' function
defence_performance_rating['Score'] = defence_performance_rating.apply(calculate_performance_defence, axis=1)

# Arrange the data by the 'Score' column
defence_performance_rating_1 = defence_performance_rating.sort_values(by='Score', ascending=False)
defence_performance_rating_1

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#             Squad              Player  Fouls_Commited  Fouls_Won  Offsides  \
# 920        Fulham       João Palhinha            52.0       56.0       2.0
# 2444    Tottenham         Pedro Porro            37.0       27.0       1.0
# 925        Fulham    Antonee Robinson            34.0       20.0       3.0
# 1233         Köln         Timo Hübers            44.0       25.0       1.0
# 1252   Las Palmas       Sergi Cardona            52.0       60.0       5.0
# ...           ...                 ...             ...        ...       ...
# 30321         NaN  Sid Ahmed Aissaoui             NaN        NaN       NaN
# 30322         NaN         Erdem Çalık             NaN        NaN       NaN
# 30323         NaN       Adama Sidibeh             NaN        NaN       NaN
# 30324         NaN  Artem Prysyazhnyuk             NaN        NaN       NaN
# 30325         NaN    Araphat Mohammed             NaN        NaN       NaN
#
#        Crosses  Penalties_Won  Penalties_Conceded  Own_Goals  Ball_Recoveries  \
# 920        5.0            0.0                 1.0        0.0            195.0
# 2444     198.0            0.0                 1.0        0.0            199.0
# 925      132.0            0.0                 0.0        2.0            227.0
# 1233       3.0            1.0                 0.0        0.0            211.0
# 1252      89.0            0.0                 0.0        0.0            188.0
# ...        ...            ...                 ...        ...              ...
# 30321      NaN            NaN                 NaN        NaN              NaN
# 30322      NaN            NaN                 NaN        NaN              NaN
# 30323      NaN            NaN                 NaN        NaN              NaN
# 30324      NaN            NaN                 NaN        NaN              NaN
# 30325      NaN            NaN                 NaN        NaN              NaN
#
#        ...   Foot  Height_in_CM  Contract_Expiration_Date        Agent_Name  \
# 920    ...  right         190.0       2028-06-30 00:00:00  Gonçalo Palhinha
# 2444   ...  right         173.0       2028-06-30 00:00:00      CAA Base Ltd
# 925    ...   left         183.0       2028-06-30 00:00:00         Wasserman
# 1233   ...  right         190.0       2026-06-30 00:00:00            11WINS
# 1252   ...   both         186.0       2024-06-30 00:00:00       EMG Mundial
# ...    ...    ...           ...                       ...               ...
# 30321  ...  right         183.0       2026-06-30 00:00:00  Aniss Benchabane
# 30322  ...  right           NaN       2026-06-30 00:00:00               NaN
# 30323  ...    NaN           NaN       2026-05-31 00:00:00      Willie McKay
# 30324  ...   left         180.0       2025-05-31 00:00:00               NaN
# 30325  ...   left           NaN                       NaN               NaN
#
#                        Current_Club_Name  Market_Value_in_Eur  \
# 920                 Fulham Football Club           55000000.0
# 2444     Tottenham Hotspur Football Club           45000000.0
# 925                 Fulham Football Club           20000000.0
# 1233                1. Fußball-Club Köln            7500000.0
# 1252   Unión Deportiva Las Palmas S.A.D.            6000000.0
# ...                                  ...                  ...
# 30321                    PFK CSKA Moskva             150000.0
# 30322                         Pendikspor              50000.0
# 30323      Saint Johnstone Football Club                  NaN
# 30324         ZAO FK Chornomorets Odessa                  NaN
# 30325          Fodbold Club Nordsjælland                  NaN
#
#        Highest_Market_Value_in_Eur  Touches  Usage_Rate_Per   Score
# 920                     60000000.0   1760.0        7.237437  6355.0
# 2444                    45000000.0   2786.0        9.765502  6259.1
# 925                     20000000.0   2536.0       10.428489  6159.2
# 1233                     8500000.0   2143.0       11.071502  5782.2
# 1252                     6000000.0   2586.0        9.563256  5764.4
# ...                            ...      ...             ...     ...
# 30321                     150000.0      NaN             NaN     NaN
# 30322                      50000.0      NaN             NaN     NaN
# 30323                          NaN      NaN             NaN     NaN
# 30324                          NaN      NaN             NaN     NaN
# 30325                          NaN      NaN             NaN     NaN
#
# [30326 rows x 96 columns]

# %%
# Filtering the data so it only keeps defenders
condition_def = (defence_performance_rating_1['Position'] == 'Defender') 

# Apply the filter to create a defender dataset
defence_performance_rating_2 = defence_performance_rating_1[condition_def]

defence_performance_rating_2 = defence_performance_rating_2.sort_values(by='Score', ascending=False)
defence_performance_rating_2.head(60)

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#                Squad                  Player  Fouls_Commited  Fouls_Won  \
# 2444       Tottenham             Pedro Porro            37.0       27.0
# 925           Fulham        Antonee Robinson            34.0       20.0
# 1233            Köln             Timo Hübers            44.0       25.0
# 1252      Las Palmas           Sergi Cardona            52.0       60.0
# 312           Bochum                Bernardo            54.0       28.0
# 657   Crystal Palace        Joachim Andersen            43.0       23.0
# 2502         Udinese            Nehuén Pérez            34.0       17.0
# 1453       Liverpool         Virgil van Dijk            23.0       13.0
# 1624  Manchester Utd             Diogo Dalot            45.0       14.0
# 820          Everton         James Tarkowski            45.0       25.0
# 2134           Reims        Emmanuel Agbadou            31.0       10.0
# 799          Everton      Jarrad Branthwaite            25.0       19.0
# 736         Dortmund      Nico Schlotterbeck            17.0       32.0
# 1090      Heidenheim          Patrick Mainka            24.0       16.0
# 2387       Stuttgart  Maximilian Mittelstädt            28.0       31.0
# 2446       Tottenham         Cristian Romero            31.0       24.0
# 2693          Wolves              Max Kilman            38.0       18.0
# 543         Cagliari         Alberto Dossena            38.0       42.0
# 1654       Marseille        Leonardo Balerdi            25.0       23.0
# 435            Brest           Bradley Locko            26.0       42.0
# 2071      RB Leipzig              David Raum            28.0       12.0
# 1368            Lens          Facundo Medina            51.0       19.0
# 671   Crystal Palace         Tyrick Mitchell            22.0       16.0
# 1924            Nice                   Dante            42.0       17.0
# 758   Eint Frankfurt           Willian Pacho            22.0       14.0
# 1710            Metz           Matthieu Udol            28.0       20.0
# 228        Barcelona            João Cancelo            40.0       26.0
# 653    Clermont Foot            Andy Pelmard            13.0       19.0
# 2699          Wolves           Nélson Semedo            48.0       30.0
# 1864          Napoli     Giovanni Di Lorenzo            28.0       37.0
# 1911   Newcastle Utd         Kieran Trippier            27.0       21.0
# 424            Brest      Brendan Chardonnet            35.0       23.0
# 1972         Osasuna             Jesús Areso            30.0       20.0
# 330           Bochum     Keven Schlotterbeck            36.0       32.0
# 2373       Stuttgart          Waldemar Anton            25.0       26.0
# 986           Getafe              Diego Rico            32.0       55.0
# 1020        Gladbach             Nico Elvedi            13.0       18.0
# 899        Frosinone             Caleb Okoli            27.0       26.0
# 1338           Lecce        Valentin Gendrey            27.0       40.0
# 100      Aston Villa              Ezri Konsa            14.0       64.0
# 2475        Toulouse       Rasmus Nicolaisen            45.0       22.0
# 1313        Le Havre          Gautier Lloris            35.0        7.0
# 764   Eint Frankfurt                    Tuta            29.0       17.0
# 2303         Sevilla            Sergio Ramos            27.0       22.0
# 240        Barcelona            Jules Koundé            22.0       16.0
# 1380      Leverkusen      Alejandro Grimaldo            14.0       26.0
# 843       Fiorentina   Lucas Martínez Quarta            41.0       13.0
# 994           Girona             Daley Blind            19.0       12.0
# 1938            Nice       Jean-Clair Todibo            25.0       18.0
# 2368      Strasbourg           Marvin Senaya            36.0       52.0
# 1556        Mainz 05       Sepp van den Berg            31.0       18.0
# 1938       0.0     12.0            0.0                 0.0        1.0
# 2368       0.0     79.0            0.0                 1.0        0.0
# 1556       0.0      2.0            0.0                 0.0        1.0
# 1043       5.0     21.0            0.0                 0.0        0.0
# 960        4.0     30.0            0.0                 1.0        0.0
# 356        1.0     39.0            0.0                 0.0        0.0
# 2601       1.0      4.0            0.0                 1.0        0.0
# 1319       0.0    190.0            1.0                 1.0        0.0
# 2133       0.0      3.0            0.0                 0.0        1.0
# 341        2.0      9.0            0.0                 2.0        1.0
# 2075       3.0     18.0            1.0                 1.0        0.0
# 2399       1.0      3.0            1.0                 1.0        0.0
#
#       Ball_Recoveries  ...   Foot  Height_in_CM  Contract_Expiration_Date  \
# 2444            199.0  ...  right         173.0       2028-06-30 00:00:00
# 925             227.0  ...   left         183.0       2028-06-30 00:00:00
# 1233            211.0  ...  right         190.0       2026-06-30 00:00:00
# 1252            188.0  ...   both         186.0       2024-06-30 00:00:00
# 312             197.0  ...   left         186.0       2025-06-30 00:00:00
# 657             193.0  ...  right         192.0       2026-06-30 00:00:00
# 2502            164.0  ...  right         186.0       2027-06-30 00:00:00
# 1453            170.0  ...  right         195.0       2025-06-30 00:00:00
# 1624            195.0  ...  right         183.0       2028-06-30 00:00:00
# 820             186.0  ...  right         185.0       2026-06-30 00:00:00
# 2134            217.0  ...  right         192.0       2027-06-30 00:00:00
# 799             181.0  ...   left         195.0       2027-06-30 00:00:00
# 736             245.0  ...   left         191.0       2027-06-30 00:00:00
# 1090            183.0  ...  right         194.0       2027-06-30 00:00:00
# 2387            140.0  ...   left         180.0       2026-06-30 00:00:00
# 2446            189.0  ...  right         185.0       2027-06-30 00:00:00
# 2693            177.0  ...   left         194.0       2028-06-30 00:00:00
# 543             190.0  ...  right         195.0       2027-06-30 00:00:00
# 1654            167.0  ...  right         187.0       2026-06-30 00:00:00
# 435             213.0  ...   left         180.0       2027-06-30 00:00:00
# 2071            169.0  ...   left         180.0       2027-06-30 00:00:00
# 1368            229.0  ...   left         184.0       2028-06-30 00:00:00
# 671             208.0  ...   left         175.0       2025-06-30 00:00:00
# 1924            219.0  ...   left         188.0       2024-06-30 00:00:00
# 758             216.0  ...   left         187.0       2028-06-30 00:00:00
# 1710            149.0  ...   left         178.0       2027-06-30 00:00:00
# 228             165.0  ...  right         182.0       2024-06-30 00:00:00
# 653             170.0  ...  right         180.0       2027-06-30 00:00:00
# 2699            188.0  ...  right         177.0       2025-06-30 00:00:00
# 1864            141.0  ...  right         183.0       2028-06-30 00:00:00
# 1911            162.0  ...  right         173.0       2025-06-30 00:00:00
# 424             174.0  ...  right         184.0       2025-06-30 00:00:00
# 1972            130.0  ...  right         182.0       2026-06-30 00:00:00
# 330             144.0  ...   left         189.0       2024-06-30 00:00:00
# 2373            203.0  ...  right         189.0       2027-06-30 00:00:00
# 986             164.0  ...   left         183.0       2024-06-30 00:00:00
# 1020            137.0  ...  right         189.0       2027-06-30 00:00:00
# 899             164.0  ...  right         191.0       2024-06-30 00:00:00
# 1338            104.0  ...  right         179.0       2026-06-30 00:00:00
# 100             142.0  ...  right         183.0       2028-06-30 00:00:00
# 2475            150.0  ...   left         191.0       2025-06-30 00:00:00
# 1313            147.0  ...   left         191.0       2026-06-30 00:00:00
# 764             171.0  ...  right         185.0       2026-06-30 00:00:00
# 2303            143.0  ...  right         184.0       2024-06-30 00:00:00
# 240             157.0  ...  right         180.0       2027-06-30 00:00:00
# 1380            168.0  ...   left         171.0       2027-06-30 00:00:00
# 843             141.0  ...  right         183.0       2025-06-30 00:00:00
# 994             147.0  ...   left         180.0       2025-06-30 00:00:00
# 1938            212.0  ...  right         190.0       2027-06-30 00:00:00
# 2368             83.0  ...  right         181.0       2027-06-30 00:00:00
# 1556            176.0  ...  right         192.0       2024-06-30 00:00:00
# 1043            147.0  ...   left         188.0       2024-06-30 00:00:00
# 960             101.0  ...   left         185.0       2027-06-30 00:00:00
# 356             109.0  ...  right         190.0       2026-06-30 00:00:00
# 2601            138.0  ...   left         187.0       2026-06-30 00:00:00
# 1319            150.0  ...   left         183.0       2026-06-30 00:00:00
# 2133            149.0  ...   left         190.0       2024-06-30 00:00:00
# 341             194.0  ...   left         188.0       2027-06-30 00:00:00
# 2075            113.0  ...  right         187.0       2027-06-30 00:00:00
# 2399            127.0  ...   left         190.0       2028-06-30 00:00:00
#
#                 Agent_Name                                  Current_Club_Name  \
# 2444          CAA Base Ltd                    Tottenham Hotspur Football Club
# 925              Wasserman                               Fulham Football Club
# 1233                11WINS                               1. Fußball-Club Köln
# 1252           EMG Mundial                  Unión Deportiva Las Palmas S.A.D.
# 312               Kick&Run  Verein für Leibesübungen Bochum 1848 – Fußball...
# 657            CAA Stellar                       Crystal Palace Football Club
# 2502                11WINS                                     Udinese Calcio
# 1453                  ROOF                            Liverpool Football Club
# 1624        Proeleven S.A.                    Manchester United Football Club
# 820                    NaN                              Everton Football Club
# 2134            Aneke/PMG                                      Stade de Reims
# 799                    NaN                              Everton Football Club
# 736       Robert Schneider                                  Borussia Dortmund
# 1090             TPWE GmbH                     1. Fußballclub Heidenheim 1846
# 2387        Sports360 GmbH          Verein für Bewegungsspiele Stuttgart 1893
# 2446          Ciro Palermo                    Tottenham Hotspur Football Club
# 2693             Wasserman              Wolverhampton Wanderers Football Club
# 543                    NaN                                    Cagliari Calcio
# 1654                    SP                             Olympique de Marseille
# 435         Victor Aupetit                                  Stade brestois 29
# 2071                  ROOF                             RasenBallsport Leipzig
# 1368                   NaN                                Racing Club de Lens
# 671          Connect Force                       Crystal Palace Football Club
# 1924          Marcus Marin           Olympique Gymnaste Club Nice Côte d'Azur
# 758          Kancha Agency                     Eintracht Frankfurt Fußball AG
# 1710                   NaN                              Football Club de Metz
# 228              Gestifute                              Futbol Club Barcelona
# 653                  ELIFA                                   Clermont Foot 63
# 2699             Gestifute              Wolverhampton Wanderers Football Club
# 1864                   NaN                     Società Sportiva Calcio Napoli
# 1911          CAA Base Ltd                     Newcastle United Football Club
# 424                NexSt11                                  Stade brestois 29
# 1972           Global Ases                              Club Atlético Osasuna
# 2399        7.020665  4717.0
#
# [60 rows x 96 columns]

# %%
# Save the datatset as CSV file with the new 'Score' feature 
defence_performance_rating_2.to_csv('file_def.csv', encoding = 'utf-8-sig', index = False)

# %%
Goalkeeper_performance_rating = performance_rating_GK

# %%
# This function will create a 'Score' for the Goalkeepers based on the criteria below
# Goalkeepers' have a much more specialised skillset
def calculate_performance_GK(col_GK):
    per_save = col_GK['Performance_Save_Per']
    pen_save_per = col_GK['Penalty_Kick_Save_Per'] * 5
    pen_kick_save = col_GK['Penalties_saved'] * 5
    Post_shot_ex = col_GK['PSxG_minus_GA'] * 10 
    Cross_stop = col_GK['Crosses_Stp_Per'] 
    Sweep = col_GK['Number_of_Sweep'] * 5
    long_pass_acc = col_GK['Long_Pass_Acc_per'] * 5
    
    return per_save + pen_save_per + pen_kick_save + Post_shot_ex + Cross_stop + Sweep + long_pass_acc

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"

# %%
# Applying the goalkeeper function to create a new variable 'score'
Goalkeeper_performance_rating['Score'] = Goalkeeper_performance_rating.apply(calculate_performance_GK, axis=1)

# Arrange the data by the 'Score' column
Goalkeeper_performance_rating_1 = Goalkeeper_performance_rating.sort_values(by='Score', ascending=False)
Goalkeeper_performance_rating_1

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#               Squad            Player Country_of_Birth Country_of_Citizenship  \
# 97       Las Palmas     Álvaro Vallés              NaN                    NaN
# 153         Osasuna    Sergio Herrera            Spain                  Spain
# 88       Hoffenheim    Oliver Baumann          Germany                Germany
# 13    Athletic Club        Unai Simón            Spain                  Spain
# 26           Bochum    Manuel Riemann          Germany                Germany
# ...             ...               ...              ...                    ...
# 6264            NaN    Lovro Zvonarek              NaN                    NaN
# 6265            NaN   Martin Ødegaard              NaN                    NaN
# 6266            NaN       Milan Đurić              NaN                    NaN
# 6267            NaN       Milan Đurić              NaN                    NaN
# 6268            NaN  Mateusz Łęgowski              NaN                    NaN
#
#              DOB    Position   Foot  Height_in_CM Contract_Expiration_Date  \
# 97           NaN         NaN    NaN           NaN                      NaN
# 153   1993-06-05  Goalkeeper  right         192.0      2026-06-30 00:00:00
# 88    1990-06-02  Goalkeeper  right         187.0      2026-06-30 00:00:00
# 13    1997-06-11  Goalkeeper  right         190.0      2025-06-30 00:00:00
# 26    1988-09-09  Goalkeeper  right         186.0      2025-06-30 00:00:00
# ...          ...         ...    ...           ...                      ...
# 6264         NaN         NaN    NaN           NaN                      NaN
# 6265         NaN         NaN    NaN           NaN                      NaN
# 6266         NaN         NaN    NaN           NaN                      NaN
# 6267         NaN         NaN    NaN           NaN                      NaN
# 6268         NaN         NaN    NaN           NaN                      NaN
#
#        Agent_Name  ... Sweeper_Avg_Dist           Comp  Performance_Save_Per  \
# 97            NaN  ...             17.8     es La Liga                  74.3
# 153     YOU FIRST  ...             16.4     es La Liga                  64.4
# 88      CN Sports  ...             16.7  de Bundesliga                  69.7
# 13    CAA Stellar  ...             16.3     es La Liga                  73.8
# 26           ROOF  ...             19.8  de Bundesliga                  67.0
# ...           ...  ...              ...            ...                   ...
# 6264          NaN  ...              NaN            NaN                   NaN
# 6265          NaN  ...              NaN            NaN                   NaN
# 6266          NaN  ...              NaN            NaN                   NaN
# 6267          NaN  ...              NaN            NaN                   NaN
# 6268          NaN  ...              NaN            NaN                   NaN
#
#      Penalties_saved Penalty Kicks PKm  Penalty_Kick_Save_Per      Rk  \
# 97               3.0               1.0                   37.5  2668.0
# 153              1.0               0.0                  100.0  1135.0
# 88               3.0               0.0                   60.0   240.0
# 13               3.0               1.0                   75.0  2440.0
# 26               2.0               0.0                   18.2  2235.0
# ...              ...               ...                    ...     ...
# 6264             NaN               NaN                    NaN  2848.0
# 6265             NaN               NaN                    NaN  2849.0
# 6266             NaN               NaN                    NaN  2850.0
# 6267             NaN               NaN                    NaN  2851.0
# 6268             NaN               NaN                    NaN  2852.0
#
#       Touches  Usage_Rate_Per  Score
# 97     2056.0        8.276639  992.4
# 153    1264.0        4.515415  991.1
# 88     1521.0        5.834516  987.9
# 13     1301.0        5.694900  952.7
# 26     1820.0        9.912314  827.4
# ...       ...             ...    ...
# 6264     73.0             NaN    NaN
# 6265   2326.0             NaN    NaN
# 6266    421.0             NaN    NaN
# 6267    381.0             NaN    NaN
# 6268    504.0             NaN    NaN
#
# [6269 rows x 40 columns]

# %%
# Filter so it is only Goalkeepers
condition_GK = (Goalkeeper_performance_rating_1['Position'] == 'Goalkeeper') 

# Apply the Goalkeeper filter to the dataset
Goalkeeper_performance_rating_2 = Goalkeeper_performance_rating_1[condition_GK]

Goalkeeper_performance_rating_2 = Goalkeeper_performance_rating_2.sort_values(by='Score', ascending=False)
Goalkeeper_performance_rating_2.head(50)

# Title: A Comprehensive Guide to the Pandas apply() Function in Python
# Author: Machine learning Tutorials
# Date: 2023
# Code Version: N/A
# Source: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
# Out:
#                Squad                  Player Country_of_Birth  \
# 153          Osasuna          Sergio Herrera            Spain
# 88        Hoffenheim          Oliver Baumann          Germany
# 13     Athletic Club              Unai Simón            Spain
# 26            Bochum          Manuel Riemann          Germany
# 28           Bologna       Federico Ravaglia            Italy
# 40           Burnley          Arijanet Muric      Switzerland
# 192         Valencia    Giorgi Mamardashvili          Georgia
# 8        Aston Villa             Robin Olsen           Sweden
# 36             Brest             Marco Bizot      Netherlands
# 56      Darmstadt 98          Marcel Schuhen          Germany
# 136            Monza     Michele Di Gregorio            Italy
# 101         Le Havre           Arthur Desmas           France
# 76            Getafe             David Soria            Spain
# 157   Rayo Vallecano      Stole Dimitrievski        Macedonia
# 164    Real Sociedad             Álex Remiro            Spain
# 185                  Italy  1996-10-07  Goalkeeper  right         194.0
# 51                 Senegal  1993-06-22  Goalkeeper  right         197.0
# 141                  Italy  1997-03-22  Goalkeeper   left         190.0
# 65                 England  1994-03-07  Goalkeeper   left         185.0
# 20                 Germany  1986-03-27  Goalkeeper  right         193.0
# 49                   Spain  1997-11-18  Goalkeeper  right         197.0
# 169                 Serbia  1999-08-27  Goalkeeper  right         189.0
# 112                Belgium  1992-10-23  Goalkeeper    NaN         190.0
# 122                 Brazil  1993-08-17  Goalkeeper   left         188.0
# 78               Argentina  1992-01-02  Goalkeeper  right         195.0
# 92                  Poland  1990-04-18  Goalkeeper  right         196.0
# 182                Germany  1996-09-30  Goalkeeper  right         193.0
# 131                  Italy  2004-01-22  Goalkeeper  right         197.0
# 66                   Italy  1990-03-08  Goalkeeper  right         193.0
# 69                 Germany  2002-05-25  Goalkeeper  right         190.0
# 166                 France  1999-11-16  Goalkeeper  right         190.0
# 24                Portugal  1994-02-07  Goalkeeper   left         191.0
# 31                  Brazil  1989-07-19  Goalkeeper  right         190.0
# 18                 Germany  1992-04-30  Goalkeeper  right         187.0
# 117                Germany  1994-10-28  Goalkeeper  right         195.0
# 196                Germany  1995-07-12  Goalkeeper   both         187.0
# 59             Switzerland  1997-12-06  Goalkeeper  right         196.0
# 3                 Portugal  1999-01-05  Goalkeeper   both         190.0
# 198                 France  1993-02-27  Goalkeeper  right         195.0
# 183                 Serbia  1997-02-20  Goalkeeper  right         202.0
# 61                 Germany  1990-07-08  Goalkeeper  right         189.0
# 201                Belgium  1992-06-25  Goalkeeper   left         197.0
#
#     Contract_Expiration_Date            Agent_Name  ... Sweeper_Avg_Dist  \
# 153      2026-06-30 00:00:00             YOU FIRST  ...             16.4
# 88       2026-06-30 00:00:00             CN Sports  ...             16.7
# 13       2025-06-30 00:00:00           CAA Stellar  ...             16.3
# 26       2025-06-30 00:00:00                  ROOF  ...             19.8
# 28       2026-06-30 00:00:00              BC Group  ...             17.1
# 40       2026-06-30 00:00:00                11WINS  ...             17.2
# 192      2027-06-30 00:00:00         Free Football  ...             12.3
# 8                        NaN                   NaN  ...              8.4
# 36       2026-06-30 00:00:00            Key United  ...             15.7
# 56       2025-06-30 00:00:00      VIDA Sports GmbH  ...             16.5
# 136      2027-06-30 00:00:00                   NaN  ...             11.5
# 101      2025-06-30 00:00:00                   NaN  ...             12.5
# 76       2026-06-30 00:00:00           Promoesport  ...             17.3
# 157      2024-06-30 00:00:00           Promoesport  ...             14.6
# 164      2027-06-30 00:00:00           Feel Winner  ...             16.9
# 9        2027-06-30 00:00:00  Universal Twenty Two  ...             17.5
# 104      2028-06-30 00:00:00           Sport Cover  ...             14.8
# 6        2024-06-30 00:00:00       FUTBOL21 AGENCY  ...             17.9
# 108      2027-06-30 00:00:00         Beckster Int.  ...             12.7
# 16       2026-06-30 00:00:00             CN Sports  ...             15.0
# 155      2026-06-30 00:00:00           Team Raiola  ...             13.2
# 12       2026-06-30 00:00:00   World Soccer Agency  ...             14.7
# 89       2026-06-30 00:00:00                   NaN  ...             12.1
# 185      2028-06-30 00:00:00                 GG11   ...             17.1
# 51       2026-06-30 00:00:00                   NaN  ...             14.4
# 141      2024-06-30 00:00:00                   NaN  ...             15.4
# 65       2027-06-30 00:00:00           CAA Stellar  ...             15.9
# 20       2025-06-30 00:00:00       PRO Profil GmbH  ...             17.5
# 49       2030-06-30 00:00:00           CAA Stellar  ...             15.8
# 169      2027-06-30 00:00:00  Universal Twenty Two  ...             12.0
# 112                      NaN                   SEG  ...             20.5
# 122      2026-06-30 00:00:00             Gestifute  ...             17.3
# 78       2027-06-30 00:00:00          LGT Football  ...             13.2
# 92       2025-06-30 00:00:00           CAA Stellar  ...             11.6
# 182      2026-06-30 00:00:00       Siebert & Backs  ...             17.3
# 131      2027-06-30 00:00:00                   NaN  ...              0.0
# 66       2025-06-30 00:00:00                   NaN  ...             14.6
# 69                       NaN   Unique Sports Group  ...             13.6
# 166      2027-06-30 00:00:00        FAIR SPORT MNG  ...             14.2
# 24       2026-06-30 00:00:00        Team of Future  ...             14.9
# 31       2026-06-30 00:00:00     Bertolucci Sports  ...             13.7
# 18       2028-06-30 00:00:00                  ROOF  ...             15.6
# 117      2025-06-30 00:00:00          W&K Fairplay  ...             16.0
# 196      2027-06-30 00:00:00           EMG Mundial  ...             14.6
# 59       2028-06-30 00:00:00     SBE Management AG  ...             12.5
# 3        2024-06-30 00:00:00     MRP.POSITIONUMBER  ...             14.5
# 198      2027-06-30 00:00:00       Rafaela Pimenta  ...              8.9
# 183      2026-06-30 00:00:00            DOO Magnum  ...             13.6
# 61       2026-06-30 00:00:00        Sports360 GmbH  ...             15.2
# 201      2024-06-30 00:00:00                   NaN  ...             15.7
#
#                    Comp  Performance_Save_Per Penalties_saved  \
# 153          es La Liga                  64.4             1.0
# 88        de Bundesliga                  69.7             3.0
# 13           es La Liga                  73.8             3.0
# 26        de Bundesliga                  67.0             2.0
# 28           it Serie A                  83.3             1.0
# 40   eng Premier League                  80.8             1.0
# 192          es La Liga                  73.8             3.0
# 8    eng Premier League                  61.8             1.0
# 36           fr Ligue 1                  75.2             1.0
# 56        de Bundesliga                  62.1             1.0
# 136          it Serie A                  79.9             2.0
# 101          fr Ligue 1                  72.5             1.0
# 76           es La Liga                  72.5             1.0
# 157          es La Liga                  69.3             1.0
# 164          es La Liga                  76.2             1.0
# 9    eng Premier League                  66.2             0.0
# 104          fr Ligue 1                  78.7             1.0
# 6    eng Premier League                  68.1             1.0
# 108          fr Ligue 1                  76.4             2.0
# 16        de Bundesliga                  71.5             2.0
# 155          fr Ligue 1                  84.5             1.0
# 12           it Serie A                  75.7             2.0
# 89           it Serie A                  82.7             1.0
# 185  eng Premier League                  67.7             0.0
# 51           fr Ligue 1                  74.5             1.0
# 141          it Serie A                  63.5             2.0
# 65   eng Premier League                  73.9             0.0
# 20        de Bundesliga                  66.7             1.0
# 49   eng Premier League                  70.5             1.0
# 169          it Serie A                  76.6             1.0
# 112  eng Premier League                  63.3             0.0
# 31                0.0                   16.7  1888.0   1138.0        5.497585
# 18                0.0                    0.0  2570.0   1080.0        3.760839
# 117               1.0                    0.0  2827.0   1123.0        5.681186
# 196               0.0                    0.0  2832.0   1200.0        5.748503
# 59                0.0                   16.7  1349.0   1239.0        5.443283
# 3                 2.0                   20.0  1679.0   1355.0        6.482633
# 198               0.0                   28.6   130.0    976.0        4.793007
# 183               0.0                    0.0  1752.0   1620.0        5.678432
# 61                0.0                   18.2  2633.0   1228.0        6.294531
# 201               1.0                    0.0   485.0   1004.0        4.275069
#
#      Score
# 153  991.1
# 88   987.9
# 13   952.7
# 26   827.4
# 28   777.7
# 40   747.8
# 192  742.3
# 8    722.3
# 36   718.9
# 56   715.4
# 136  696.0
# 101  684.8
# 76   680.2
# 157  678.1
# 164  675.4
# 9    673.3
# 104  662.4
# 6    661.3
# 108  636.8
# 16   629.3
# 155  629.1
# 12   625.2
# 89   623.8
# 185  617.2
# 51   615.4
# 141  612.2
# 65   593.2
# 20   592.6
# 49   585.9
# 169  585.8
# 112  579.7
# 122  574.3
# 78   572.3
# 92   569.3
# 182  557.5
# 131  549.0
# 66   537.3
# 69   531.6
# 166  526.4
# 24   526.1
# 31   520.5
# 18   516.9
# 117  513.5
# 196  502.1
# 59   486.8
# 3    478.3
# 198  475.3
# 183  472.1
# 61   470.5
# 201  465.8
#
# [50 rows x 40 columns]

# %%
# Save the dataset with new the Goalkeeper 'Score' as CSV
Goalkeeper_performance_rating_2.to_csv('file_GK.csv', encoding = 'utf-8-sig', index = False)

# %%
'''Reference List

Machine learning Tutorials (2023) A Comprehensive Guide to the Pandas apply() Function in Python. Machine learning Tutorials
Available at: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"
[Accessed on: 15th June 2024]

Pandas (No date) Title: User Guide - Pandas. Pandas [online]. Available at: "https://pandas.pydata.org/docs/user_guide/index.html"
[Accessed on: 5th August 2024]

Shaw and Holland (2019) Hierarchical Big data landscape Model. Research In Progress. 
In: Lecture notes and personal correspondence. Algorithms I. CP Holland, Loughborough University, (2024).

W3 Schools (No date) Pandas DataFrame isin() Method. W3 Schools.
Available at: "https://www.w3schools.com/python/pandas/ref_df_isin.asp"
[Accessed on: 6th June 2024]
'''
# Out:
# 'Reference List\n\nMachine learning Tutorials (2023) A Comprehensive Guide to the Pandas apply() Function in Python. Machine learning Tutorials\nAvailable at: "https://machinelearningtutorials.org/a-comprehensive-guide-to-the-pandas-apply-function-in-python/"\n[Accessed on: 15th June 2024]\n\nPandas (No date) Title: User Guide - Pandas. Pandas [online]. Available at: "https://pandas.pydata.org/docs/user_guide/index.html"\n[Accessed on: 5th August 2024]\n\nShaw and Holland (2019) Hierarchical Big data landscape Model. Research In Progress. \nIn: Lecture notes and personal correspondence. Algorithms I. CP Holland, Loughborough University, (2024).\n\nW3 Schools (No date) Pandas DataFrame isin() Method. W3 Schools.\nAvailable at: "https://www.w3schools.com/python/pandas/ref_df_isin.asp"\n[Accessed on: 6th June 2024]\n'
